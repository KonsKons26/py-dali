# %%
import sys
import os


sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
print(sys.path[-1])
# Out:
# /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali

# %%
BASE_DIR = os.path.dirname(os.getcwd())
META_DIR = os.path.join(BASE_DIR, "meta")
DATA_DIR = os.path.join(BASE_DIR, "data")
QUERIES_META_DIR = os.path.join(META_DIR, "queries")

os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(QUERIES_META_DIR, exist_ok=True)

print(f"{'BASE_DIR':<20}{BASE_DIR}")
print(f"{'META_DIR':<20}{META_DIR}")
print(f"{'DATA_DIR':<20}{DATA_DIR}")
print(f"{'QUERIES_META_DIR':<20}{QUERIES_META_DIR}")
# Out:
# BASE_DIR            /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali
# META_DIR            /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali/meta
# DATA_DIR            /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali/data
# QUERIES_META_DIR    /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali/meta/queries

# %%
import pandas as pd
import random

from src.utils import select_domains, download_and_process_domains

# %%
df = pd.read_csv(
    os.path.join(META_DIR, "astral.csv")
)
df
# Out:
#       domain_id  scop_code class  fold  superfamily  family pdb_id chain  \
# 0       d1dlwa_    a.1.1.1     a     1            1       1   1dlw     A
# 1       d2gkma_    a.1.1.1     a     1            1       1   2gkm     A
# 2       d1ngka_    a.1.1.1     a     1            1       1   1ngk     A
# 3       d2bkma_    a.1.1.1     a     1            1       1   2bkm     A
# 4       d4i0va_    a.1.1.1     a     1            1       1   4i0v     A
# ...         ...        ...   ...   ...          ...     ...    ...   ...
# 15172   d6id0n_   g.99.1.1     g    99            1       1   6id0     N
# 15173   d5lj3n2  g.100.1.1     g   100            1       1   5lj3     N
# 15174   d5syba_  g.101.1.1     g   101            1       1   5syb     A
# 15175   d5fyza2  g.102.1.0     g   102            1       0   5fyz     A
# 15176   d4g26a2  g.103.1.1     g   103            1       1   4g26     A
#
#       residues                                       protein_name  \
# ...

# %%
seed = 42
n = 5
m = 25

rng = random.Random(seed)

# %%
# Select domains
domains = select_domains(df, n, m, rng)
for query, reference in domains.items():
    print(f"Query: {query}, References: {reference["domain_id"].tolist()}")
    reference.to_csv(
        os.path.join(QUERIES_META_DIR, f"{query}.csv"),
        index=False
    )
    print(f"Saved {query} metadata to {os.path.join(QUERIES_META_DIR, f'{query}.csv')}")
    print()
# Out:
# Query: d3jbra3, References: ['d3jbra3', 'd2a26a1', 'd2fswa1', 'd5ocna_', 'd3mwma_', 'd2zhja_', 'd4b9pa_', 'd1rj8a_', 'd3cu7ad', 'd1ug1a1', 'd7k3ta_', 'd4k29a_', 'd1vq8c1', 'd1ozha2', 'd2f9wa1', 'd2cu2a2', 'd3zzha_', 'd4x04a1', 'd1ir6a_', 'd2i9wa1', 'd1tdja2', 'd7dl8c_', 'd3gwya1', 'd5hhaa_', 'd1hr6a1', 'd1b9wa2', 'd1nkzb_', 'd3prna_', 'd1po0a_', 'd6hcpa_', 'd5foka1', 'd5dl7a_', 'd1lsha3', 'd3c0na2', 'd6m0rd1', 'd1kf6c_', 'd2qi9a_', 'd1m56d_', 'd1q90a3', 'd4pv1e_', 'd4ogqf_', 'd5b5ej_', 'd5b5et_', 'd2zxeb1', 'd2zxeg_', 'd3ar4a1', 'd6gs4a_', 'd2onkc1', 'd4p79a1', 'd5lc5h_', 'd3rkoa_', 'd3kg2a3', 'd1orsc1', 'd2ih3c_', 'd1lnqa2', 'd6o9ua1', 'd5vkqa2', 'd6bcoa2', 'd4dxwa_', 'd6vwxa_', 'd3jbra1', 'd3jbra2', 'd3jbra4', 'd6mwdb1']
# Saved d3jbra3 metadata to /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali/meta/queries/d3jbra3.csv
#
# ...

# %%
# Download and process domains
download_and_process_domains(domains, DATA_DIR)
# Out:
# Starting domain processing. Output will be saved in '/home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali/data'
#
# Processing main query: d3jbra3...
#
# Processing domain: d3jbra3 (PDB: 3jbr, Chain: A)...
#   -> Selecting residues: '1103:1395'
#   -> SUCCESS: Saved to /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali/data/d3jbra3/d3jbra3.pdb
#
# Processing associated references for d3jbra3...
#
# Processing domain: d2a26a1 (PDB: 2a26, Chain: A)...
#   -> Selecting residues: '1:47'
#   -> SUCCESS: Saved to /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali/data/d3jbra3/references/d2a26a1.pdb
#
# Processing domain: d2fswa1 (PDB: 2fsw, Chain: A)...
#   -> Selecting residues: '3:104'
#   -> SUCCESS: Saved to /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali/data/d3jbra3/references/d2fswa1.pdb
#
# Processing domain: d5ocna_ (PDB: 5ocn, Chain: A)...
#   -> Selecting entire chain (no residues specified).
# ...
