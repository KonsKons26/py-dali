# %%
import sys
import os


sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
print(sys.path[-1])
# Out:
# /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali

# %%
from src.utils import quick_load
from src.monte_carlo import MonteCarloProteinAligner

# %%
BASE_DIR = os.path.dirname(os.getcwd())
REDUCED_DIRS = os.path.join(BASE_DIR, "reduced")

print("BASE_DIR:", BASE_DIR)
print("REDUCED_DIRS:", REDUCED_DIRS)
# Out:
# BASE_DIR: /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali
# REDUCED_DIRS: /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali/reduced

# %%
sample1 = quick_load(
    os.path.join(REDUCED_DIRS, "1euv_A.pkl.gz")
)

sample2 = quick_load(
    os.path.join(REDUCED_DIRS, "1tgz_A.pkl.gz")
)

# %%
mca = MonteCarloProteinAligner(
    sample1, sample2
)
mca.run_simulation(verbose=True)
mca.set_temperature_schedule(initial_temp=10.0, final_temp=0.1, schedule_type="linear")
mca.plot_convergence()
# Out:
# Iteration 1000: Current Score = 120.841, Best Score = 127.707, Acceptance Rate = 0.311
# Iteration 2000: Current Score = 136.481, Best Score = 145.237, Acceptance Rate = 0.244
# Iteration 3000: Current Score = 148.970, Best Score = 150.971, Acceptance Rate = 0.222
# Iteration 4000: Current Score = 147.318, Best Score = 157.133, Acceptance Rate = 0.197
# Iteration 5000: Current Score = 147.499, Best Score = 157.133, Acceptance Rate = 0.184
# Iteration 6000: Current Score = 151.304, Best Score = 158.720, Acceptance Rate = 0.187
# Iteration 7000: Current Score = 167.963, Best Score = 173.025, Acceptance Rate = 0.187
# Iteration 8000: Current Score = 159.950, Best Score = 173.025, Acceptance Rate = 0.181
# Iteration 9000: Current Score = 154.172, Best Score = 173.025, Acceptance Rate = 0.190
# Iteration 10000: Current Score = 153.044, Best Score = 173.025, Acceptance Rate = 0.208
#
# Simulation completed!
# Best score: 173.025
# Final acceptance rate: 0.208
# Best alignment has 99 matched patterns
