# %%
import sys
import os


sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))
print(sys.path[-1])
# Out:
# /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali

# %%
from src.utils import quick_load
from src.monte_carlo_claude import MonteCarloProteinAligner

# %%
BASE_DIR = os.path.dirname(os.getcwd())
REDUCED_DIRS = os.path.join(BASE_DIR, "reduced")

print("BASE_DIR:", BASE_DIR)
print("REDUCED_DIRS:", REDUCED_DIRS)
# Out:
# BASE_DIR: /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali
# REDUCED_DIRS: /home/cotsios/dsit/2nd-semester/algos-in-mol-bio/py-dali/reduced

# %%
sample1 = quick_load(
    os.path.join(REDUCED_DIRS, "1euv_A.pkl.gz")
)

sample2 = quick_load(
    os.path.join(REDUCED_DIRS, "1tgz_A.pkl.gz")
)

# %%
mca = MonteCarloProteinAligner(
    sample1, sample2
)
mca.run_simulation(verbose=True)
mca.set_temperature_schedule(initial_temp=10.0, final_temp=0.1, schedule_type="linear")
mca.plot_convergence()
# Out:
# Iteration 1000: Current Score = 145.033, Best Score = 145.562, Acceptance Rate = 0.295
# Iteration 2000: Current Score = 162.130, Best Score = 165.205, Acceptance Rate = 0.240
# Iteration 3000: Current Score = 157.076, Best Score = 165.205, Acceptance Rate = 0.199
# Iteration 4000: Current Score = 157.788, Best Score = 165.205, Acceptance Rate = 0.190
# Iteration 5000: Current Score = 151.308, Best Score = 165.759, Acceptance Rate = 0.182
# Iteration 6000: Current Score = 164.870, Best Score = 165.759, Acceptance Rate = 0.192
# Iteration 7000: Current Score = 172.202, Best Score = 176.571, Acceptance Rate = 0.187
# Iteration 8000: Current Score = 165.337, Best Score = 176.571, Acceptance Rate = 0.178
# Iteration 9000: Current Score = 162.266, Best Score = 176.571, Acceptance Rate = 0.173
# Iteration 10000: Current Score = 163.722, Best Score = 176.571, Acceptance Rate = 0.178
#
# Simulation completed!
# Best score: 176.571
# Final acceptance rate: 0.178
# ...
